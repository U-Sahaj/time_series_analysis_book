# %% [markdown]
# # Chapter 10 - Deep Learning for Time Series

# %%
import pandas as pd

# %matplotlib inline
# THIS BREAKS IT:
# %load_ext lab_black

# %% [markdown]
# Let's model airplane passengers. We'll forecast the monthly number of passengers.
# This dataset is considered one of the classic time-series, published by George E.P.
# Box and Gwilym Jenkins alongside the book "Time-Series Analysis: Forecasting and
# Control" (1976).

# %%
url_airline_passengers = "https://raw.githubusercontent.com/benman1/Machine-Learning-for-Time-Series-with-Python/main/chapter10/passengers.csv"


def get_passengers():
    df = pd.read_csv(url_airline_passengers, parse_dates=["date"]).set_index("date")
    return df


passengers = get_passengers()
passengers.head()
# Out:
#             passengers
# date
# 1949-01-31       112.0
# 1949-02-28       118.0
# 1949-03-31       132.0
# 1949-04-30       129.0
# 1949-05-31       121.0

# %%
pd.read_csv(url_airline_passengers, parse_dates=["date"])
# Out:
#           date  passengers
# 0   1949-01-31       112.0
# 1   1949-02-28       118.0
# 2   1949-03-31       132.0
# 3   1949-04-30       129.0
# 4   1949-05-31       121.0
# ..         ...         ...
# 139 1960-08-31       606.0
# 140 1960-09-30       508.0
# 141 1960-10-31       461.0
# 142 1960-11-30       390.0
# 143 1960-12-31       432.0
#
# [144 rows x 2 columns]

# %%
passengers.head()
# Out:
#             passengers
# date
# 1949-01-31       112.0
# 1949-02-28       118.0
# 1949-03-31       132.0
# 1949-04-30       129.0
# 1949-05-31       121.0

# %%
passengers.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# We'll first start with a simple FCN and then we'll apply a recurrent network, and
# finally, we'll apply a very recent architecture, a Dilated Causal Convolutional Neural
# Network.
# The FCN is first.

# %% [markdown]
# # Fully connected network
# In this first practice session, we'll use TensorFlow libraries, which we can quickly
# install from the terminal (or similarly from the anaconda navigator):

# %% [markdown]
# Let's try naively to just use an FCN, also known as an MLP.
# Let's set some imports and set a couple of global constants:

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Input, Dropout

# %%
DROPOUT_RATIO = 0.2  # Dropout ratio typically between 0.2 and 0.5
HIDDEN_NEURONS = 100

callback = keras.callbacks.EarlyStopping(
    monitor="loss", patience=5
)  # patience = number of epochs to wait if no change in loss

# %% [markdown]
# We will use these constants for our model architecture.
#
# *Dropout (or: Dilution)* is a regularization technique that can help reducing
# overfitting. Dropout means that during training, a fraction of the connections (in
# our case 20%) is randomly removed.
# Early stopping is another form of regularization, where the training stops as defined
# by certain conditions. In our case, we've stated it should stop if our loss doesn't
# improve three times in a row. If the model stops improving, there's no point in
# continuing to train it, although we may be trapped in a local minimum of the error
# that we might be able to escape. One of the big advantages of early stopping is that
# it can help us quickly see whether a model is working.
#
#
# We can define our model in this function:

# %%
def create_model(passengers):
    """Create a model to predict the number of passengers on a monthly basis."""
    input_layer = Input(len(passengers.columns))

    hiden_layer = Dropout(DROPOUT_RATIO)(input_layer)
    hiden_layer = Dense(HIDDEN_NEURONS, activation="relu")(hiden_layer)

    output_layer = Dropout(DROPOUT_RATIO)(hiden_layer)
    output_layer = Dense(1)(output_layer)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        loss="mse",
        optimizer=keras.optimizers.Adam(),
        metrics=[
            keras.metrics.RootMeanSquaredError(),
            keras.metrics.MeanAbsoluteError(),
        ],
    )
    return model

# %% [markdown]
# With the Keras functional API, we've defined a two-layer neural network, where
# the hidden layer of HIDDEN_NEURONS neurons is activated by the Rectified Linear Unit
# (ReLU) function.
# Let's split our dataset into training and test sets. We will predict the number of
# passengers based on passengers in the previous time period (previous month):

# %%
passengers = get_passengers()
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    passengers, passengers.passengers.shift(-1), shuffle=False
)

# %%
import numpy as np

np.shape(X_train), np.shape(X_test)
# Out:
# ((108, 1), (36, 1))

# %% [markdown]
# We'll learn based on the first 75% of the dataset – this is the default value for the
# test_size parameter in the train_test_split function.
#
# We can now train our naïve FCN:

# %%
model = create_model(X_train)
model.fit(X_train, y_train, epochs=1000, callbacks=[callback])
predicted = model.predict(X_test)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 72772.6016 - root_mean_squared_error: 269.7640 - mean_absolute_error: 252.4258
# Epoch 2/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 69564.2422 - root_mean_squared_error: 263.7503 - mean_absolute_error: 246.2359
# Epoch 3/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 64150.3672 - root_mean_squared_error: 253.2792 - mean_absolute_error: 237.9106
# Epoch 4/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 60572.8164 - root_mean_squared_error: 246.1154 - mean_absolute_error: 230.7828
# Epoch 5/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 56856.5664 - root_mean_squared_error: 238.4462 - mean_absolute_error: 223.1194
# Epoch 6/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 53169.6758 - root_mean_squared_error: 230.5855 - mean_absolute_error: 215.9802
# Epoch 7/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 46751.0938 - root_mean_squared_error: 216.2200 - mean_absolute_error: 203.8133
# Epoch 8/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 46363.2539 - root_mean_squared_error: 215.3213 - mean_absolute_error: 200.5618
# Epoch 9/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 40629.1211 - root_mean_squared_error: 201.5667 - mean_absolute_error: 188.0907
# Epoch 10/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 38208.9883 - root_mean_squared_error: 195.4712 - mean_absolute_error: 182.7424
# Epoch 11/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 36932.6953 - root_mean_squared_error: 192.1788 - mean_absolute_error: 177.3609
# Epoch 12/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 34653.7969 - root_mean_squared_error: 186.1553 - mean_absolute_error: 172.5362
# Epoch 13/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 33409.2930 - root_mean_squared_error: 182.7821 - mean_absolute_error: 167.0219
# Epoch 14/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 27482.0645 - root_mean_squared_error: 165.7771 - mean_absolute_error: 150.4678
# Epoch 15/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 26803.4258 - root_mean_squared_error: 163.7175 - mean_absolute_error: 149.4238
# Epoch 16/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 28215.4844 - root_mean_squared_error: 167.9747 - mean_absolute_error: 149.9990
# Epoch 17/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 23861.8887 - root_mean_squared_error: 154.4729 - mean_absolute_error: 135.6792
# Epoch 18/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 22675.8027 - root_mean_squared_error: 150.5849 - mean_absolute_error: 129.2871
# Epoch 19/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 20026.5605 - root_mean_squared_error: 141.5152 - mean_absolute_error: 118.8774
# Epoch 20/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 17573.9297 - root_mean_squared_error: 132.5667 - mean_absolute_error: 111.8206
# Epoch 21/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 17243.3242 - root_mean_squared_error: 131.3138 - mean_absolute_error: 107.5913
# Epoch 22/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 18523.3965 - root_mean_squared_error: 136.1007 - mean_absolute_error: 107.9399
# Epoch 23/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 15602.9385 - root_mean_squared_error: 124.9117 - mean_absolute_error: 96.0020
# Epoch 24/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 17592.9473 - root_mean_squared_error: 132.6384 - mean_absolute_error: 103.0370
# Epoch 25/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 11973.9199 - root_mean_squared_error: 109.4254 - mean_absolute_error: 80.7022
# Epoch 26/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 17965.9512 - root_mean_squared_error: 134.0371 - mean_absolute_error: 90.7069
# Epoch 27/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 16138.8242 - root_mean_squared_error: 127.0387 - mean_absolute_error: 86.0658
# Epoch 28/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 12023.8438 - root_mean_squared_error: 109.6533 - mean_absolute_error: 70.2576
# Epoch 29/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 23316.6172 - root_mean_squared_error: 152.6978 - mean_absolute_error: 106.5898
# Epoch 30/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 14281.6943 - root_mean_squared_error: 119.5060 - mean_absolute_error: 75.7823
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x16dc29af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 2ms/step

# %% [markdown]
# Ideally, we would see the error (loss) going down, and we'd see a low error at the
# end. I haven't included any code to fix the random number generator (tf.random.
# set_seed), so your output might differ.
# We can then get the predictions for the test set like this:

# %%
predicted
# Out:
# array([[244.88852],
#        [229.08179],
#        [260.69522],
#        [250.63641],
#        [261.4137 ],
#        [313.14484],
#        [353.38013],
#        [363.43896],
#        [290.8717 ],
#        [258.53976],
#        [223.33386],
#        [242.73303],
#        [259.25824],
#        [246.32547],
#        [292.30872],
#        [285.12384],
#        [302.3675 ],
#        [339.72888],
#        [394.33392],
#        [402.2373 ],
#        [333.26248],
#        [293.02716],
#        [260.69522],
#        [291.5902 ],
#        [300.21207],
#        [281.53137],
#        [301.64902],
#        [331.8255 ],
#        [339.72888],
#        [384.9936 ],
#        [447.502  ],
#        [436.00623],
#        [365.5944 ],
#        [331.8255 ],
#        [280.81287],
#        [310.98935]], dtype=float32)

# %% [markdown]
# Now, it would be good to visualize passenger predictions against the actual
# passenger values.
# We can use this function:

# %%
import matplotlib.pyplot as plt


def show_result(y_test, predicted, ylabel="Passengers"):
    """Plot the test data and the predicted values."""
    plt.figure(figsize=(16, 6))
    plt.plot(y_test.index, predicted, "o-", label="predicted")
    plt.plot(y_test.index, y_test, ".-", label="actual")
    plt.ylabel(ylabel)
    plt.legend()

# %%
show_result(y_test, predicted)

# %% [markdown]
# is systematically under-predicting – it has learned the baseline from the years 1949-
# 1958 of the training set, when far fewer passengers were traveling.
# Let's make this a bit more sophisticated and better.
#
# This first model was trained only on the immediate previous number of travelers.
# As a first step, we'll include the year and the month as predictor variables. The
# year can be used to model the trend, while the month is coupled to the monthly
# variability – so this seems a natural step.
#
# This will add month and year columns to the DataFrame based on the
# `DateTimeIndex:`

# %%
# passengers["year"] = passengers.index.year.values - passengers.index.year.values.min()
# passengers["month"] = passengers.index.month.values - 1

passengers["month"] = passengers.index.month.values
passengers["year"] = passengers.index.year.values

passengers.head()
# Out:
#             passengers  month  year
# date
# 1949-01-31       112.0      1  1949
# 1949-02-28       118.0      2  1949
# 1949-03-31       132.0      3  1949
# 1949-04-30       129.0      4  1949
# 1949-05-31       121.0      5  1949

# %%
# Now another round of training

X_train, X_test, y_train, y_test = train_test_split(
    passengers, passengers.passengers.shift(-1), shuffle=False
)

np.shape(X_train), np.shape(X_test)
# Out:
# ((108, 3), (36, 3))

# %%
# redefine model - add more inputs


model = create_model(X_train)

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[callback])
predicted = model.predict(X_test)
show_result(y_test, predicted)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 199918.7344 - root_mean_squared_error: 447.1227 - mean_absolute_error: 399.3007
# Epoch 2/100
# 4/4 [==============================] - 0s 1ms/step - loss: 126016.3906 - root_mean_squared_error: 354.9879 - mean_absolute_error: 318.1098
# Epoch 3/100
# 4/4 [==============================] - 0s 1ms/step - loss: 69609.6172 - root_mean_squared_error: 263.8363 - mean_absolute_error: 212.1997
# Epoch 4/100
# 4/4 [==============================] - 0s 1ms/step - loss: 44414.9766 - root_mean_squared_error: 210.7486 - mean_absolute_error: 175.8708
# Epoch 5/100
# 4/4 [==============================] - 0s 1ms/step - loss: 42392.5781 - root_mean_squared_error: 205.8946 - mean_absolute_error: 165.8154
# Epoch 6/100
# 4/4 [==============================] - 0s 1ms/step - loss: 41800.1406 - root_mean_squared_error: 204.4508 - mean_absolute_error: 164.7318
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 49352.5000 - root_mean_squared_error: 222.1542 - mean_absolute_error: 170.6826
# Epoch 8/100
# 4/4 [==============================] - 0s 1ms/step - loss: 48001.4727 - root_mean_squared_error: 219.0924 - mean_absolute_error: 182.1446
# Epoch 9/100
# 4/4 [==============================] - 0s 1ms/step - loss: 38456.9102 - root_mean_squared_error: 196.1043 - mean_absolute_error: 156.8594
# Epoch 10/100
# 4/4 [==============================] - 0s 1ms/step - loss: 40663.7969 - root_mean_squared_error: 201.6527 - mean_absolute_error: 167.0501
# Epoch 11/100
# 4/4 [==============================] - 0s 1ms/step - loss: 37883.8281 - root_mean_squared_error: 194.6377 - mean_absolute_error: 157.1559
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 40142.0586 - root_mean_squared_error: 200.3548 - mean_absolute_error: 162.9724
# Epoch 13/100
# 4/4 [==============================] - 0s 1ms/step - loss: 31715.6523 - root_mean_squared_error: 178.0889 - mean_absolute_error: 148.9660
# Epoch 14/100
# 4/4 [==============================] - 0s 1ms/step - loss: 28606.4121 - root_mean_squared_error: 169.1343 - mean_absolute_error: 137.0253
# Epoch 15/100
# 4/4 [==============================] - 0s 1ms/step - loss: 34340.2539 - root_mean_squared_error: 185.3112 - mean_absolute_error: 144.9425
# Epoch 16/100
# 4/4 [==============================] - 0s 1ms/step - loss: 31536.2246 - root_mean_squared_error: 177.5844 - mean_absolute_error: 147.0873
# Epoch 17/100
# 4/4 [==============================] - 0s 1ms/step - loss: 32178.4082 - root_mean_squared_error: 179.3834 - mean_absolute_error: 143.3406
# Epoch 18/100
# 4/4 [==============================] - 0s 1ms/step - loss: 31741.3477 - root_mean_squared_error: 178.1610 - mean_absolute_error: 146.4219
# Epoch 19/100
# 4/4 [==============================] - 0s 1ms/step - loss: 25386.3848 - root_mean_squared_error: 159.3311 - mean_absolute_error: 124.0883
# Epoch 20/100
# 4/4 [==============================] - 0s 1ms/step - loss: 31852.9102 - root_mean_squared_error: 178.4738 - mean_absolute_error: 140.4334
# Epoch 21/100
# 4/4 [==============================] - 0s 1ms/step - loss: 30595.9531 - root_mean_squared_error: 174.9170 - mean_absolute_error: 133.3890
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 26033.4082 - root_mean_squared_error: 161.3487 - mean_absolute_error: 124.7040
# Epoch 23/100
# 4/4 [==============================] - 0s 1ms/step - loss: 30001.9629 - root_mean_squared_error: 173.2108 - mean_absolute_error: 127.9826
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 40542.9180 - root_mean_squared_error: 201.3527 - mean_absolute_error: 160.9748
# 2/2 [==============================] - 0s 11ms/step

# %% [markdown]
# Please note that, because of the high number of parameters, and the randomness
# involved in the learning process, the outcome might differ significantly between
# runs. This is indeed one of the problems associated with deep learning.
#
# This already looks much better. The year feature helped our model learn the
# baseline. The model has learned something about the monthly variability, but it's not
# enough to really approximate it.
#
# Let's create a less naïve version. We will change a few things in this model:
#
# • We'll add an embedding of the month feature
# • We'll treat the year as a linear predictor
# • We'll add the previous month's passengers to our predictions
# • Finally, we'll scale our predictions based on the standard deviation in the
# training dataset
#
# That was quite a mouthful. Let's go through these a bit more slowly.
#
# We fed the months as values from 1 to 12 into our previous model. However, we
# could intuitively guess that January (1) and December (12) are perhaps more similar
# than November (11) and December. We know that there are lots of travelers in both
# December and January, but perhaps a much lower volume in November. We can
# capture these relationships based on the data.
#
# This can be done in an embedding layer. An embedding layer is a mapping of
# distinct categories to real numbers. This mapping is updated as part of the network
# optimization.
#
# The year is closely related to the overall trend. Each year, the number of airline
# passengers increases. We can model this relationship non-linearly or linearly. Here,
# I've decided to just model a linear relationship between the year feature and the
# outcome.
#
# The relationship between the previous month's passenger numbers and those in this
# month is again assumed to be linear.
#
# Finally, we can scale our predictions, similar to the inverse transformation of the
# standard transformation. You should remember the standard normalization from `Chap 3`

# %% [markdown]
# ## FFN with embedding

# %% [markdown]
# We'll need a few more imports first:

# %%
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Input
from tensorflow.keras.metrics import MeanAbsoluteError, RootMeanSquaredError

# %% [markdown]
# Now, we redefine our network as follows:

# %%
def create_model(train):
    """Create a model to predict the number of passengers on a monthly basis.
    With the use of an embedding layer and a dense layer."""
    scale = tf.constant(train.passengers.std())
    scale = tf.cast(scale, tf.float32)
    continuous_layer = Input(shape=1)

    categorical_months_layer = Input(shape=1)
    embedded_months = Embedding(12, 5)(categorical_months_layer)
    embedded_flat_months = Flatten()(embedded_months)

    year_input = Input(shape=1)
    year_layer = Dense(1)(year_input)

    hidden_output = Concatenate(-1)(
        [embedded_flat_months, year_layer, continuous_layer]
    )
    output_layer = Dense(1)(hidden_output)
    output = output_layer * scale + continuous_layer

    model = keras.models.Model(
        inputs=[continuous_layer, categorical_months_layer, year_input],
        outputs=output,
    )
    model.compile(
        loss="mse",
        optimizer=keras.optimizers.Adam(),
        metrics=[RootMeanSquaredError(), MeanAbsoluteError()],
    )
    return model

# %% [markdown]
# We reinitialise our data and model

# %%
passengers = get_passengers()
passengers["year"] = passengers.index.year.values - passengers.index.year.values.min()
passengers["month"] = passengers.index.month.values - 1
passengers.head()
# Out:
#             passengers  year  month
# date
# 1949-01-31       112.0     0      0
# 1949-02-28       118.0     0      1
# 1949-03-31       132.0     0      2
# 1949-04-30       129.0     0      3
# 1949-05-31       121.0     0      4

# %% [markdown]
# During training and for prediction purposes, we need to feed the three types of input
# separately like this:

# %%
X_train, X_test, y_train, y_test = train_test_split(
    passengers, passengers.passengers.shift(-1), shuffle=False
)

# %%
X_train.dtypes
# Out:
# passengers    float64
# year            int64
# month           int64
# dtype: object

# %%
model = create_model(X_train)

model.fit(
    (X_train["passengers"], X_train["month"], X_train["year"]), 
    y_train,
    epochs=1000,
    callbacks=[callback],
)
predicted = model.predict((X_test["passengers"], X_test["month"], X_test["year"]))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 27959816.0000 - root_mean_squared_error: 5287.7041 - mean_absolute_error: 4962.5117
# Epoch 2/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 27058710.0000 - root_mean_squared_error: 5201.7988 - mean_absolute_error: 4882.2554
# Epoch 3/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 26209014.0000 - root_mean_squared_error: 5119.4741 - mean_absolute_error: 4803.3618
# Epoch 4/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 25339240.0000 - root_mean_squared_error: 5033.8096 - mean_absolute_error: 4723.1729
# Epoch 5/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 24505390.0000 - root_mean_squared_error: 4950.2920 - mean_absolute_error: 4644.7974
# Epoch 6/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 23667772.0000 - root_mean_squared_error: 4864.9536 - mean_absolute_error: 4565.2036
# Epoch 7/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 22847996.0000 - root_mean_squared_error: 4779.9575 - mean_absolute_error: 4486.2090
# Epoch 8/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 22050616.0000 - root_mean_squared_error: 4695.8081 - mean_absolute_error: 4407.6357
# Epoch 9/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 21279576.0000 - root_mean_squared_error: 4612.9790 - mean_absolute_error: 4329.7095
# Epoch 10/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 20518620.0000 - root_mean_squared_error: 4529.7485 - mean_absolute_error: 4251.4878
# Epoch 11/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 19796114.0000 - root_mean_squared_error: 4449.2822 - mean_absolute_error: 4174.7754
# Epoch 12/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 19074850.0000 - root_mean_squared_error: 4367.4766 - mean_absolute_error: 4098.2925
# Epoch 13/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 18377032.0000 - root_mean_squared_error: 4286.8442 - mean_absolute_error: 4023.0371
# Epoch 14/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 17723722.0000 - root_mean_squared_error: 4209.9551 - mean_absolute_error: 3949.5010
# Epoch 15/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 17036494.0000 - root_mean_squared_error: 4127.5288 - mean_absolute_error: 3874.2693
# Epoch 16/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 16430057.0000 - root_mean_squared_error: 4053.4006 - mean_absolute_error: 3803.0496
# Epoch 17/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 15800201.0000 - root_mean_squared_error: 3974.9468 - mean_absolute_error: 3730.1831
# Epoch 18/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 15198988.0000 - root_mean_squared_error: 3898.5879 - mean_absolute_error: 3658.2781
# Epoch 19/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 14612008.0000 - root_mean_squared_error: 3822.5657 - mean_absolute_error: 3587.0237
# Epoch 20/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 14050450.0000 - root_mean_squared_error: 3748.3931 - mean_absolute_error: 3516.8083
# Epoch 21/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 13500389.0000 - root_mean_squared_error: 3674.2876 - mean_absolute_error: 3447.1162
# Epoch 22/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 12977604.0000 - root_mean_squared_error: 3602.4441 - mean_absolute_error: 3378.9312
# Epoch 23/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 12443919.0000 - root_mean_squared_error: 3527.5940 - mean_absolute_error: 3310.4541
# Epoch 24/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 11963893.0000 - root_mean_squared_error: 3458.8860 - mean_absolute_error: 3244.7427
# Epoch 25/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 11467149.0000 - root_mean_squared_error: 3386.3179 - mean_absolute_error: 3177.5151
# Epoch 26/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 11010071.0000 - root_mean_squared_error: 3318.1428 - mean_absolute_error: 3112.4731
# Epoch 27/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 10543452.0000 - root_mean_squared_error: 3247.0681 - mean_absolute_error: 3046.4419
# Epoch 28/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 10104745.0000 - root_mean_squared_error: 3178.7961 - mean_absolute_error: 2981.7974
# Epoch 29/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 9663676.0000 - root_mean_squared_error: 3108.6453 - mean_absolute_error: 2917.1094
# Epoch 30/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 9266440.0000 - root_mean_squared_error: 3044.0828 - mean_absolute_error: 2854.6172
# Epoch 31/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 8856248.0000 - root_mean_squared_error: 2975.9448 - mean_absolute_error: 2790.8042
# Epoch 32/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 8460119.0000 - root_mean_squared_error: 2908.6284 - mean_absolute_error: 2728.0845
# Epoch 33/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 8091169.0000 - root_mean_squared_error: 2844.4980 - mean_absolute_error: 2667.5520
# Epoch 34/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 7725030.0000 - root_mean_squared_error: 2779.3938 - mean_absolute_error: 2607.4670
# Epoch 35/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 7392219.5000 - root_mean_squared_error: 2718.8635 - mean_absolute_error: 2549.2485
# Epoch 36/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 7048247.5000 - root_mean_squared_error: 2654.8535 - mean_absolute_error: 2490.0276
# Epoch 37/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 6727423.5000 - root_mean_squared_error: 2593.7278 - mean_absolute_error: 2432.4219
# Epoch 38/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 6419628.0000 - root_mean_squared_error: 2533.6985 - mean_absolute_error: 2375.9675
# Epoch 39/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 6117209.0000 - root_mean_squared_error: 2473.2993 - mean_absolute_error: 2319.7151
# Epoch 40/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 5842948.0000 - root_mean_squared_error: 2417.2190 - mean_absolute_error: 2265.3901
# Epoch 41/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 5552225.0000 - root_mean_squared_error: 2356.3159 - mean_absolute_error: 2208.9651
# Epoch 42/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 5286804.5000 - root_mean_squared_error: 2299.3052 - mean_absolute_error: 2155.3784
# Epoch 43/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 5027304.5000 - root_mean_squared_error: 2242.1650 - mean_absolute_error: 2102.5356
# Epoch 44/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 4794821.0000 - root_mean_squared_error: 2189.7080 - mean_absolute_error: 2052.2166
# Epoch 45/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 4566767.0000 - root_mean_squared_error: 2136.9995 - mean_absolute_error: 2001.8488
# Epoch 46/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 4332529.0000 - root_mean_squared_error: 2081.4729 - mean_absolute_error: 1950.9783
# Epoch 47/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 4125030.7500 - root_mean_squared_error: 2031.0172 - mean_absolute_error: 1903.4125
# Epoch 48/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 3921533.7500 - root_mean_squared_error: 1980.2863 - mean_absolute_error: 1855.4641
# Epoch 49/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 3717139.7500 - root_mean_squared_error: 1927.9885 - mean_absolute_error: 1807.4022
# Epoch 50/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 3531453.2500 - root_mean_squared_error: 1879.2162 - mean_absolute_error: 1761.0294
# Epoch 51/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 3348615.5000 - root_mean_squared_error: 1829.9222 - mean_absolute_error: 1714.6478
# Epoch 52/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 3175754.2500 - root_mean_squared_error: 1782.0646 - mean_absolute_error: 1668.7311
# Epoch 53/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 3008108.2500 - root_mean_squared_error: 1734.3899 - mean_absolute_error: 1623.7532
# Epoch 54/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2844867.0000 - root_mean_squared_error: 1686.6733 - mean_absolute_error: 1579.6196
# Epoch 55/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2696701.7500 - root_mean_squared_error: 1642.1637 - mean_absolute_error: 1537.3413
# Epoch 56/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2555412.7500 - root_mean_squared_error: 1598.5658 - mean_absolute_error: 1495.8107
# Epoch 57/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2414629.0000 - root_mean_squared_error: 1553.9077 - mean_absolute_error: 1454.5148
# Epoch 58/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2284920.0000 - root_mean_squared_error: 1511.5952 - mean_absolute_error: 1414.7196
# Epoch 59/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2159422.0000 - root_mean_squared_error: 1469.4972 - mean_absolute_error: 1375.2585
# Epoch 60/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2042006.3750 - root_mean_squared_error: 1428.9879 - mean_absolute_error: 1337.1636
# Epoch 61/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1931787.5000 - root_mean_squared_error: 1389.8876 - mean_absolute_error: 1299.8522
# Epoch 62/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1822401.1250 - root_mean_squared_error: 1349.9634 - mean_absolute_error: 1262.5519
# Epoch 63/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1719253.7500 - root_mean_squared_error: 1311.2031 - mean_absolute_error: 1226.3378
# Epoch 64/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1621523.5000 - root_mean_squared_error: 1273.3905 - mean_absolute_error: 1190.4305
# Epoch 65/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1526033.7500 - root_mean_squared_error: 1235.3274 - mean_absolute_error: 1154.7487
# Epoch 66/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1434638.2500 - root_mean_squared_error: 1197.7638 - mean_absolute_error: 1119.8387
# Epoch 67/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1351246.2500 - root_mean_squared_error: 1162.4312 - mean_absolute_error: 1086.1121
# Epoch 68/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 1273537.0000 - root_mean_squared_error: 1128.5110 - mean_absolute_error: 1053.4125
# Epoch 69/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1193631.3750 - root_mean_squared_error: 1092.5344 - mean_absolute_error: 1020.3878
# Epoch 70/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1120647.2500 - root_mean_squared_error: 1058.6063 - mean_absolute_error: 988.6601
# Epoch 71/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1052089.0000 - root_mean_squared_error: 1025.7139 - mean_absolute_error: 957.9395
# Epoch 72/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 989588.9375 - root_mean_squared_error: 994.7808 - mean_absolute_error: 928.2639
# Epoch 73/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 927346.7500 - root_mean_squared_error: 962.9885 - mean_absolute_error: 898.4314
# Epoch 74/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 868968.5000 - root_mean_squared_error: 932.1848 - mean_absolute_error: 869.5462
# Epoch 75/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 815666.2500 - root_mean_squared_error: 903.1425 - mean_absolute_error: 841.6469
# Epoch 76/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 762319.6250 - root_mean_squared_error: 873.1092 - mean_absolute_error: 813.8122
# Epoch 77/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 713050.3750 - root_mean_squared_error: 844.4231 - mean_absolute_error: 787.1353
# Epoch 78/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 669085.7500 - root_mean_squared_error: 817.9766 - mean_absolute_error: 761.7125
# Epoch 79/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 625035.2500 - root_mean_squared_error: 790.5917 - mean_absolute_error: 736.0728
# Epoch 80/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 584605.6875 - root_mean_squared_error: 764.5951 - mean_absolute_error: 711.5582
# Epoch 81/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 546724.3750 - root_mean_squared_error: 739.4081 - mean_absolute_error: 687.5345
# Epoch 82/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 509775.9375 - root_mean_squared_error: 713.9860 - mean_absolute_error: 663.8636
# Epoch 83/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 475774.9688 - root_mean_squared_error: 689.7644 - mean_absolute_error: 641.0279
# Epoch 84/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 443277.8750 - root_mean_squared_error: 665.7911 - mean_absolute_error: 618.5728
# Epoch 85/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 413890.2188 - root_mean_squared_error: 643.3430 - mean_absolute_error: 596.9585
# Epoch 86/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 384036.3750 - root_mean_squared_error: 619.7067 - mean_absolute_error: 575.4309
# Epoch 87/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 357439.1250 - root_mean_squared_error: 597.8621 - mean_absolute_error: 554.9186
# Epoch 88/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 333258.1250 - root_mean_squared_error: 577.2852 - mean_absolute_error: 535.0735
# Epoch 89/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 309277.1250 - root_mean_squared_error: 556.1269 - mean_absolute_error: 515.3857
# Epoch 90/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 287874.2188 - root_mean_squared_error: 536.5391 - mean_absolute_error: 496.6355
# Epoch 91/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 267437.5938 - root_mean_squared_error: 517.1437 - mean_absolute_error: 478.2154
# Epoch 92/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 248221.9375 - root_mean_squared_error: 498.2188 - mean_absolute_error: 460.4983
# Epoch 93/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 230634.3281 - root_mean_squared_error: 480.2440 - mean_absolute_error: 443.5034
# Epoch 94/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 214015.6406 - root_mean_squared_error: 462.6183 - mean_absolute_error: 426.9332
# Epoch 95/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 198349.0938 - root_mean_squared_error: 445.3640 - mean_absolute_error: 410.7088
# Epoch 96/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 183985.4062 - root_mean_squared_error: 428.9352 - mean_absolute_error: 395.0027
# Epoch 97/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 169928.5156 - root_mean_squared_error: 412.2239 - mean_absolute_error: 379.4183
# Epoch 98/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 157116.0781 - root_mean_squared_error: 396.3787 - mean_absolute_error: 364.4883
# Epoch 99/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 145516.6250 - root_mean_squared_error: 381.4664 - mean_absolute_error: 350.2032
# Epoch 100/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 134789.8906 - root_mean_squared_error: 367.1374 - mean_absolute_error: 336.3463
# Epoch 101/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 124215.9609 - root_mean_squared_error: 352.4428 - mean_absolute_error: 322.6203
# Epoch 102/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 114896.0469 - root_mean_squared_error: 338.9632 - mean_absolute_error: 309.7315
# Epoch 103/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 105894.9688 - root_mean_squared_error: 325.4151 - mean_absolute_error: 297.2337
# Epoch 104/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 97899.0703 - root_mean_squared_error: 312.8883 - mean_absolute_error: 285.3553
# Epoch 105/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 90548.5938 - root_mean_squared_error: 300.9129 - mean_absolute_error: 273.9622
# Epoch 106/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 83641.7422 - root_mean_squared_error: 289.2088 - mean_absolute_error: 262.8443
# Epoch 107/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 77087.8359 - root_mean_squared_error: 277.6470 - mean_absolute_error: 251.9229
# Epoch 108/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 71110.0000 - root_mean_squared_error: 266.6646 - mean_absolute_error: 241.3701
# Epoch 109/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 65229.1250 - root_mean_squared_error: 255.3999 - mean_absolute_error: 230.9323
# Epoch 110/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 60112.1680 - root_mean_squared_error: 245.1778 - mean_absolute_error: 221.0947
# Epoch 111/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 55349.6094 - root_mean_squared_error: 235.2650 - mean_absolute_error: 211.4219
# Epoch 112/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 50814.1094 - root_mean_squared_error: 225.4198 - mean_absolute_error: 202.1030
# Epoch 113/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 46694.1445 - root_mean_squared_error: 216.0883 - mean_absolute_error: 193.2915
# Epoch 114/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 42720.9531 - root_mean_squared_error: 206.6905 - mean_absolute_error: 184.5675
# Epoch 115/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 39328.2227 - root_mean_squared_error: 198.3134 - mean_absolute_error: 176.3129
# Epoch 116/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 35958.5039 - root_mean_squared_error: 189.6273 - mean_absolute_error: 168.0490
# Epoch 117/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 33034.5352 - root_mean_squared_error: 181.7541 - mean_absolute_error: 160.2770
# Epoch 118/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 30169.7285 - root_mean_squared_error: 173.6944 - mean_absolute_error: 152.7050
# Epoch 119/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 27589.5742 - root_mean_squared_error: 166.1011 - mean_absolute_error: 145.5133
# Epoch 120/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 25291.7324 - root_mean_squared_error: 159.0338 - mean_absolute_error: 138.6118
# Epoch 121/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 23088.7910 - root_mean_squared_error: 151.9500 - mean_absolute_error: 131.9236
# Epoch 122/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 21209.1094 - root_mean_squared_error: 145.6335 - mean_absolute_error: 125.4989
# Epoch 123/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 19342.9023 - root_mean_squared_error: 139.0788 - mean_absolute_error: 119.2433
# Epoch 124/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 17617.1387 - root_mean_squared_error: 132.7296 - mean_absolute_error: 113.1879
# Epoch 125/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 16156.7139 - root_mean_squared_error: 127.1091 - mean_absolute_error: 107.5410
# Epoch 126/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 14754.0137 - root_mean_squared_error: 121.4661 - mean_absolute_error: 101.9660
# Epoch 127/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 13526.4287 - root_mean_squared_error: 116.3032 - mean_absolute_error: 96.8097
# Epoch 128/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 12424.3564 - root_mean_squared_error: 111.4646 - mean_absolute_error: 91.8847
# Epoch 129/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 11310.8975 - root_mean_squared_error: 106.3527 - mean_absolute_error: 87.1001
# Epoch 130/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 10463.6328 - root_mean_squared_error: 102.2919 - mean_absolute_error: 82.7477
# Epoch 131/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 9597.3809 - root_mean_squared_error: 97.9662 - mean_absolute_error: 78.5475
# Epoch 132/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 8849.2188 - root_mean_squared_error: 94.0703 - mean_absolute_error: 74.5474
# Epoch 133/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 8153.8970 - root_mean_squared_error: 90.2989 - mean_absolute_error: 70.7477
# Epoch 134/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 7511.8184 - root_mean_squared_error: 86.6707 - mean_absolute_error: 67.1411
# Epoch 135/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 6920.9385 - root_mean_squared_error: 83.1922 - mean_absolute_error: 63.7686
# Epoch 136/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 6425.7153 - root_mean_squared_error: 80.1606 - mean_absolute_error: 60.6196
# Epoch 137/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 5946.1216 - root_mean_squared_error: 77.1111 - mean_absolute_error: 57.5851
# Epoch 138/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 5512.4712 - root_mean_squared_error: 74.2460 - mean_absolute_error: 54.7701
# Epoch 139/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 5128.4019 - root_mean_squared_error: 71.6129 - mean_absolute_error: 52.1769
# Epoch 140/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 4760.3232 - root_mean_squared_error: 68.9951 - mean_absolute_error: 49.7188
# Epoch 141/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 4435.4380 - root_mean_squared_error: 66.5991 - mean_absolute_error: 47.3962
# Epoch 142/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 4135.6289 - root_mean_squared_error: 64.3089 - mean_absolute_error: 45.1778
# Epoch 143/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 3852.7036 - root_mean_squared_error: 62.0702 - mean_absolute_error: 43.1233
# Epoch 144/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 3603.5740 - root_mean_squared_error: 60.0298 - mean_absolute_error: 41.3120
# Epoch 145/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 3364.6201 - root_mean_squared_error: 58.0053 - mean_absolute_error: 39.5435
# Epoch 146/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 3167.7092 - root_mean_squared_error: 56.2824 - mean_absolute_error: 38.0975
# Epoch 147/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2963.1833 - root_mean_squared_error: 54.4351 - mean_absolute_error: 36.5629
# Epoch 148/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2802.7332 - root_mean_squared_error: 52.9408 - mean_absolute_error: 35.3321
# Epoch 149/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2626.6704 - root_mean_squared_error: 51.2511 - mean_absolute_error: 34.1114
# Epoch 150/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2496.1260 - root_mean_squared_error: 49.9612 - mean_absolute_error: 33.1850
# Epoch 151/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2373.7556 - root_mean_squared_error: 48.7212 - mean_absolute_error: 32.3098
# Epoch 152/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2250.3252 - root_mean_squared_error: 47.4376 - mean_absolute_error: 31.4983
# Epoch 153/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2152.9353 - root_mean_squared_error: 46.3997 - mean_absolute_error: 30.7808
# Epoch 154/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2062.5857 - root_mean_squared_error: 45.4157 - mean_absolute_error: 30.1280
# Epoch 155/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1983.5110 - root_mean_squared_error: 44.5366 - mean_absolute_error: 29.6061
# Epoch 156/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1907.7335 - root_mean_squared_error: 43.6776 - mean_absolute_error: 29.1719
# Epoch 157/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1845.3182 - root_mean_squared_error: 42.9572 - mean_absolute_error: 28.8100
# Epoch 158/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1785.3618 - root_mean_squared_error: 42.2535 - mean_absolute_error: 28.4197
# Epoch 159/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1725.4314 - root_mean_squared_error: 41.5383 - mean_absolute_error: 28.0738
# Epoch 160/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1665.6501 - root_mean_squared_error: 40.8124 - mean_absolute_error: 27.6764
# Epoch 161/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1622.9635 - root_mean_squared_error: 40.2860 - mean_absolute_error: 27.4234
# Epoch 162/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1577.0470 - root_mean_squared_error: 39.7121 - mean_absolute_error: 27.2143
# Epoch 163/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1530.5483 - root_mean_squared_error: 39.1222 - mean_absolute_error: 26.9756
# Epoch 164/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1498.7045 - root_mean_squared_error: 38.7131 - mean_absolute_error: 26.8258
# Epoch 165/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1466.3468 - root_mean_squared_error: 38.2929 - mean_absolute_error: 26.5792
# Epoch 166/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1441.2810 - root_mean_squared_error: 37.9642 - mean_absolute_error: 26.4738
# Epoch 167/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1421.2517 - root_mean_squared_error: 37.6995 - mean_absolute_error: 26.3679
# Epoch 168/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1392.6444 - root_mean_squared_error: 37.3181 - mean_absolute_error: 26.2437
# Epoch 169/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1376.0671 - root_mean_squared_error: 37.0954 - mean_absolute_error: 26.1725
# Epoch 170/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1359.0463 - root_mean_squared_error: 36.8652 - mean_absolute_error: 26.0762
# Epoch 171/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1345.2167 - root_mean_squared_error: 36.6772 - mean_absolute_error: 26.0156
# Epoch 172/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1331.7826 - root_mean_squared_error: 36.4936 - mean_absolute_error: 25.9833
# Epoch 173/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1320.3120 - root_mean_squared_error: 36.3361 - mean_absolute_error: 25.9433
# Epoch 174/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1309.1958 - root_mean_squared_error: 36.1828 - mean_absolute_error: 25.8733
# Epoch 175/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1298.0576 - root_mean_squared_error: 36.0286 - mean_absolute_error: 25.8434
# Epoch 176/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1290.9911 - root_mean_squared_error: 35.9304 - mean_absolute_error: 25.8158
# Epoch 177/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1279.2466 - root_mean_squared_error: 35.7666 - mean_absolute_error: 25.7564
# Epoch 178/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1273.8516 - root_mean_squared_error: 35.6911 - mean_absolute_error: 25.7568
# Epoch 179/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1265.6896 - root_mean_squared_error: 35.5765 - mean_absolute_error: 25.7277
# Epoch 180/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1259.0205 - root_mean_squared_error: 35.4827 - mean_absolute_error: 25.6922
# Epoch 181/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1253.5402 - root_mean_squared_error: 35.4054 - mean_absolute_error: 25.6855
# Epoch 182/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1246.5425 - root_mean_squared_error: 35.3064 - mean_absolute_error: 25.6578
# Epoch 183/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1241.8497 - root_mean_squared_error: 35.2399 - mean_absolute_error: 25.6282
# Epoch 184/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1237.0991 - root_mean_squared_error: 35.1724 - mean_absolute_error: 25.6083
# Epoch 185/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1231.1664 - root_mean_squared_error: 35.0880 - mean_absolute_error: 25.5938
# Epoch 186/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1225.9213 - root_mean_squared_error: 35.0132 - mean_absolute_error: 25.5616
# Epoch 187/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1221.6990 - root_mean_squared_error: 34.9528 - mean_absolute_error: 25.5418
# Epoch 188/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1217.3639 - root_mean_squared_error: 34.8907 - mean_absolute_error: 25.5379
# Epoch 189/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1212.9065 - root_mean_squared_error: 34.8268 - mean_absolute_error: 25.5192
# Epoch 190/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1209.1023 - root_mean_squared_error: 34.7721 - mean_absolute_error: 25.5002
# Epoch 191/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1205.4675 - root_mean_squared_error: 34.7198 - mean_absolute_error: 25.4969
# Epoch 192/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1202.3829 - root_mean_squared_error: 34.6754 - mean_absolute_error: 25.4831
# Epoch 193/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1199.3282 - root_mean_squared_error: 34.6313 - mean_absolute_error: 25.4837
# Epoch 194/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1196.9110 - root_mean_squared_error: 34.5964 - mean_absolute_error: 25.4986
# Epoch 195/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1193.1622 - root_mean_squared_error: 34.5422 - mean_absolute_error: 25.4939
# Epoch 196/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1190.3284 - root_mean_squared_error: 34.5011 - mean_absolute_error: 25.4796
# Epoch 197/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1187.5454 - root_mean_squared_error: 34.4608 - mean_absolute_error: 25.4734
# Epoch 198/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1185.0940 - root_mean_squared_error: 34.4252 - mean_absolute_error: 25.4790
# Epoch 199/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1182.3759 - root_mean_squared_error: 34.3857 - mean_absolute_error: 25.4812
# Epoch 200/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1180.9095 - root_mean_squared_error: 34.3644 - mean_absolute_error: 25.4940
# Epoch 201/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1177.2664 - root_mean_squared_error: 34.3113 - mean_absolute_error: 25.4754
# Epoch 202/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1175.1031 - root_mean_squared_error: 34.2798 - mean_absolute_error: 25.4566
# Epoch 203/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1172.8993 - root_mean_squared_error: 34.2476 - mean_absolute_error: 25.4356
# Epoch 204/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1170.7915 - root_mean_squared_error: 34.2168 - mean_absolute_error: 25.4154
# Epoch 205/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1168.5747 - root_mean_squared_error: 34.1844 - mean_absolute_error: 25.4026
# Epoch 206/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1166.2950 - root_mean_squared_error: 34.1511 - mean_absolute_error: 25.3907
# Epoch 207/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1163.9537 - root_mean_squared_error: 34.1168 - mean_absolute_error: 25.3778
# Epoch 208/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1161.7728 - root_mean_squared_error: 34.0848 - mean_absolute_error: 25.3620
# Epoch 209/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1160.2808 - root_mean_squared_error: 34.0629 - mean_absolute_error: 25.3623
# Epoch 210/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1157.8519 - root_mean_squared_error: 34.0272 - mean_absolute_error: 25.3514
# Epoch 211/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1155.1810 - root_mean_squared_error: 33.9880 - mean_absolute_error: 25.3272
# Epoch 212/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1153.5139 - root_mean_squared_error: 33.9634 - mean_absolute_error: 25.3094
# Epoch 213/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1150.7491 - root_mean_squared_error: 33.9227 - mean_absolute_error: 25.2895
# Epoch 214/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1148.4849 - root_mean_squared_error: 33.8893 - mean_absolute_error: 25.2663
# Epoch 215/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1146.4979 - root_mean_squared_error: 33.8600 - mean_absolute_error: 25.2506
# Epoch 216/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1144.1981 - root_mean_squared_error: 33.8260 - mean_absolute_error: 25.2270
# Epoch 217/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1141.9802 - root_mean_squared_error: 33.7932 - mean_absolute_error: 25.2008
# Epoch 218/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1139.6945 - root_mean_squared_error: 33.7594 - mean_absolute_error: 25.1855
# Epoch 219/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1137.6102 - root_mean_squared_error: 33.7285 - mean_absolute_error: 25.1664
# Epoch 220/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1135.6337 - root_mean_squared_error: 33.6992 - mean_absolute_error: 25.1490
# Epoch 221/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1133.4229 - root_mean_squared_error: 33.6663 - mean_absolute_error: 25.1363
# Epoch 222/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1130.8792 - root_mean_squared_error: 33.6285 - mean_absolute_error: 25.1070
# Epoch 223/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1128.8087 - root_mean_squared_error: 33.5977 - mean_absolute_error: 25.0800
# Epoch 224/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1126.4711 - root_mean_squared_error: 33.5629 - mean_absolute_error: 25.0611
# Epoch 225/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1124.3300 - root_mean_squared_error: 33.5310 - mean_absolute_error: 25.0446
# Epoch 226/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1122.2063 - root_mean_squared_error: 33.4993 - mean_absolute_error: 25.0239
# Epoch 227/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1120.0299 - root_mean_squared_error: 33.4668 - mean_absolute_error: 24.9929
# Epoch 228/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1118.1522 - root_mean_squared_error: 33.4388 - mean_absolute_error: 24.9594
# Epoch 229/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1115.9038 - root_mean_squared_error: 33.4051 - mean_absolute_error: 24.9289
# Epoch 230/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1113.6161 - root_mean_squared_error: 33.3709 - mean_absolute_error: 24.9082
# Epoch 231/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1111.7795 - root_mean_squared_error: 33.3434 - mean_absolute_error: 24.8857
# Epoch 232/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1109.4209 - root_mean_squared_error: 33.3080 - mean_absolute_error: 24.8504
# Epoch 233/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1107.2903 - root_mean_squared_error: 33.2760 - mean_absolute_error: 24.8096
# Epoch 234/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1105.3518 - root_mean_squared_error: 33.2468 - mean_absolute_error: 24.7745
# Epoch 235/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1103.3142 - root_mean_squared_error: 33.2162 - mean_absolute_error: 24.7347
# Epoch 236/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1100.5393 - root_mean_squared_error: 33.1744 - mean_absolute_error: 24.7065
# Epoch 237/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1099.0846 - root_mean_squared_error: 33.1524 - mean_absolute_error: 24.7027
# Epoch 238/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1096.3763 - root_mean_squared_error: 33.1116 - mean_absolute_error: 24.6909
# Epoch 239/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1094.0743 - root_mean_squared_error: 33.0768 - mean_absolute_error: 24.6655
# Epoch 240/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1091.8646 - root_mean_squared_error: 33.0434 - mean_absolute_error: 24.6386
# Epoch 241/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1089.7205 - root_mean_squared_error: 33.0109 - mean_absolute_error: 24.6205
# Epoch 242/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1087.4127 - root_mean_squared_error: 32.9759 - mean_absolute_error: 24.6131
# Epoch 243/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1085.5382 - root_mean_squared_error: 32.9475 - mean_absolute_error: 24.6060
# Epoch 244/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1083.4500 - root_mean_squared_error: 32.9158 - mean_absolute_error: 24.5981
# Epoch 245/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1081.0219 - root_mean_squared_error: 32.8789 - mean_absolute_error: 24.5690
# Epoch 246/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1078.6511 - root_mean_squared_error: 32.8428 - mean_absolute_error: 24.5408
# Epoch 247/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1076.4865 - root_mean_squared_error: 32.8099 - mean_absolute_error: 24.5258
# Epoch 248/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1074.5938 - root_mean_squared_error: 32.7810 - mean_absolute_error: 24.5060
# Epoch 249/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1072.3295 - root_mean_squared_error: 32.7464 - mean_absolute_error: 24.4645
# Epoch 250/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1069.9789 - root_mean_squared_error: 32.7105 - mean_absolute_error: 24.4176
# Epoch 251/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1067.6830 - root_mean_squared_error: 32.6754 - mean_absolute_error: 24.3863
# Epoch 252/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1065.5703 - root_mean_squared_error: 32.6431 - mean_absolute_error: 24.3573
# Epoch 253/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1063.2628 - root_mean_squared_error: 32.6077 - mean_absolute_error: 24.3301
# Epoch 254/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1060.7705 - root_mean_squared_error: 32.5695 - mean_absolute_error: 24.3126
# Epoch 255/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1058.6862 - root_mean_squared_error: 32.5375 - mean_absolute_error: 24.2941
# Epoch 256/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1056.4333 - root_mean_squared_error: 32.5028 - mean_absolute_error: 24.2748
# Epoch 257/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1054.3546 - root_mean_squared_error: 32.4708 - mean_absolute_error: 24.2715
# Epoch 258/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1051.9419 - root_mean_squared_error: 32.4337 - mean_absolute_error: 24.2612
# Epoch 259/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1049.8247 - root_mean_squared_error: 32.4010 - mean_absolute_error: 24.2413
# Epoch 260/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1048.2587 - root_mean_squared_error: 32.3768 - mean_absolute_error: 24.2348
# Epoch 261/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1045.4113 - root_mean_squared_error: 32.3328 - mean_absolute_error: 24.2065
# Epoch 262/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1043.2327 - root_mean_squared_error: 32.2991 - mean_absolute_error: 24.1690
# Epoch 263/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1040.8820 - root_mean_squared_error: 32.2627 - mean_absolute_error: 24.1339
# Epoch 264/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1038.7858 - root_mean_squared_error: 32.2302 - mean_absolute_error: 24.1110
# Epoch 265/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1037.0017 - root_mean_squared_error: 32.2025 - mean_absolute_error: 24.1096
# Epoch 266/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1034.1659 - root_mean_squared_error: 32.1585 - mean_absolute_error: 24.1022
# Epoch 267/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1032.1112 - root_mean_squared_error: 32.1265 - mean_absolute_error: 24.0849
# Epoch 268/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1031.3521 - root_mean_squared_error: 32.1147 - mean_absolute_error: 24.0957
# Epoch 269/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1027.9559 - root_mean_squared_error: 32.0618 - mean_absolute_error: 24.0810
# Epoch 270/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1025.6954 - root_mean_squared_error: 32.0265 - mean_absolute_error: 24.0557
# Epoch 271/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1023.3862 - root_mean_squared_error: 31.9904 - mean_absolute_error: 24.0229
# Epoch 272/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1021.0051 - root_mean_squared_error: 31.9532 - mean_absolute_error: 23.9791
# Epoch 273/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1018.7708 - root_mean_squared_error: 31.9182 - mean_absolute_error: 23.9364
# Epoch 274/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1016.2383 - root_mean_squared_error: 31.8785 - mean_absolute_error: 23.8856
# Epoch 275/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1013.9430 - root_mean_squared_error: 31.8425 - mean_absolute_error: 23.8231
# Epoch 276/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1011.7439 - root_mean_squared_error: 31.8079 - mean_absolute_error: 23.7672
# Epoch 277/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1009.6487 - root_mean_squared_error: 31.7750 - mean_absolute_error: 23.7392
# Epoch 278/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1007.0515 - root_mean_squared_error: 31.7341 - mean_absolute_error: 23.7093
# Epoch 279/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1004.8552 - root_mean_squared_error: 31.6995 - mean_absolute_error: 23.6630
# Epoch 280/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1002.6289 - root_mean_squared_error: 31.6643 - mean_absolute_error: 23.6052
# Epoch 281/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1000.2960 - root_mean_squared_error: 31.6275 - mean_absolute_error: 23.5414
# Epoch 282/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 998.3372 - root_mean_squared_error: 31.5965 - mean_absolute_error: 23.4837
# Epoch 283/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 996.2832 - root_mean_squared_error: 31.5640 - mean_absolute_error: 23.4235
# Epoch 284/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 994.0228 - root_mean_squared_error: 31.5281 - mean_absolute_error: 23.3817
# Epoch 285/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 991.9306 - root_mean_squared_error: 31.4949 - mean_absolute_error: 23.3468
# Epoch 286/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 989.5815 - root_mean_squared_error: 31.4576 - mean_absolute_error: 23.3150
# Epoch 287/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 987.6175 - root_mean_squared_error: 31.4264 - mean_absolute_error: 23.2870
# Epoch 288/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 985.1755 - root_mean_squared_error: 31.3875 - mean_absolute_error: 23.2451
# Epoch 289/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 983.1914 - root_mean_squared_error: 31.3559 - mean_absolute_error: 23.1970
# Epoch 290/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 980.8628 - root_mean_squared_error: 31.3187 - mean_absolute_error: 23.1511
# Epoch 291/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 978.7715 - root_mean_squared_error: 31.2853 - mean_absolute_error: 23.1017
# Epoch 292/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 976.4590 - root_mean_squared_error: 31.2483 - mean_absolute_error: 23.0552
# Epoch 293/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 974.5382 - root_mean_squared_error: 31.2176 - mean_absolute_error: 23.0303
# Epoch 294/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 972.3942 - root_mean_squared_error: 31.1832 - mean_absolute_error: 23.0067
# Epoch 295/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 970.5195 - root_mean_squared_error: 31.1532 - mean_absolute_error: 22.9590
# Epoch 296/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 968.1476 - root_mean_squared_error: 31.1151 - mean_absolute_error: 22.9082
# Epoch 297/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 965.8676 - root_mean_squared_error: 31.0784 - mean_absolute_error: 22.8836
# Epoch 298/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 964.1613 - root_mean_squared_error: 31.0509 - mean_absolute_error: 22.8709
# Epoch 299/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 961.7857 - root_mean_squared_error: 31.0127 - mean_absolute_error: 22.8357
# Epoch 300/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 959.5825 - root_mean_squared_error: 30.9771 - mean_absolute_error: 22.7896
# Epoch 301/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 957.6001 - root_mean_squared_error: 30.9451 - mean_absolute_error: 22.7464
# Epoch 302/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 955.3680 - root_mean_squared_error: 30.9090 - mean_absolute_error: 22.7166
# Epoch 303/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 954.0526 - root_mean_squared_error: 30.8877 - mean_absolute_error: 22.7116
# Epoch 304/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 951.4216 - root_mean_squared_error: 30.8451 - mean_absolute_error: 22.6788
# Epoch 305/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 949.3331 - root_mean_squared_error: 30.8112 - mean_absolute_error: 22.6389
# Epoch 306/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 947.1321 - root_mean_squared_error: 30.7755 - mean_absolute_error: 22.6148
# Epoch 307/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 945.2094 - root_mean_squared_error: 30.7443 - mean_absolute_error: 22.6050
# Epoch 308/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 943.0527 - root_mean_squared_error: 30.7092 - mean_absolute_error: 22.5843
# Epoch 309/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 940.8781 - root_mean_squared_error: 30.6737 - mean_absolute_error: 22.5666
# Epoch 310/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 938.7892 - root_mean_squared_error: 30.6397 - mean_absolute_error: 22.5450
# Epoch 311/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 936.9921 - root_mean_squared_error: 30.6103 - mean_absolute_error: 22.5155
# Epoch 312/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 934.8895 - root_mean_squared_error: 30.5760 - mean_absolute_error: 22.4790
# Epoch 313/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 932.6783 - root_mean_squared_error: 30.5398 - mean_absolute_error: 22.4514
# Epoch 314/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 930.5095 - root_mean_squared_error: 30.5043 - mean_absolute_error: 22.4136
# Epoch 315/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 928.4738 - root_mean_squared_error: 30.4709 - mean_absolute_error: 22.3732
# Epoch 316/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 926.4028 - root_mean_squared_error: 30.4369 - mean_absolute_error: 22.3457
# ...
# Epoch 894/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 315.1029 - root_mean_squared_error: 17.7511 - mean_absolute_error: 13.1082
# Epoch 895/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 314.7093 - root_mean_squared_error: 17.7400 - mean_absolute_error: 13.1100
# Epoch 896/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 314.5442 - root_mean_squared_error: 17.7354 - mean_absolute_error: 13.1178
# Epoch 897/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 314.1350 - root_mean_squared_error: 17.7239 - mean_absolute_error: 13.1100
# Epoch 898/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 313.9218 - root_mean_squared_error: 17.7178 - mean_absolute_error: 13.1014
# Epoch 899/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 313.6982 - root_mean_squared_error: 17.7115 - mean_absolute_error: 13.0960
# Epoch 900/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 313.3148 - root_mean_squared_error: 17.7007 - mean_absolute_error: 13.0851
# Epoch 901/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 313.3104 - root_mean_squared_error: 17.7006 - mean_absolute_error: 13.0712
# Epoch 902/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 313.1136 - root_mean_squared_error: 17.6950 - mean_absolute_error: 13.0500
# Epoch 903/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 313.2289 - root_mean_squared_error: 17.6983 - mean_absolute_error: 13.0505
# Epoch 904/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 312.9691 - root_mean_squared_error: 17.6909 - mean_absolute_error: 13.0496
# Epoch 905/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 312.3213 - root_mean_squared_error: 17.6726 - mean_absolute_error: 13.0478
# Epoch 906/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 312.0894 - root_mean_squared_error: 17.6661 - mean_absolute_error: 13.0449
# Epoch 907/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 311.8527 - root_mean_squared_error: 17.6594 - mean_absolute_error: 13.0414
# Epoch 908/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 311.5915 - root_mean_squared_error: 17.6520 - mean_absolute_error: 13.0378
# Epoch 909/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 311.3604 - root_mean_squared_error: 17.6454 - mean_absolute_error: 13.0352
# Epoch 910/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 311.1199 - root_mean_squared_error: 17.6386 - mean_absolute_error: 13.0366
# Epoch 911/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 310.8406 - root_mean_squared_error: 17.6307 - mean_absolute_error: 13.0340
# Epoch 912/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 310.5420 - root_mean_squared_error: 17.6222 - mean_absolute_error: 13.0399
# Epoch 913/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 310.3180 - root_mean_squared_error: 17.6158 - mean_absolute_error: 13.0624
# Epoch 914/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 310.3037 - root_mean_squared_error: 17.6154 - mean_absolute_error: 13.0719
# Epoch 915/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 310.0404 - root_mean_squared_error: 17.6080 - mean_absolute_error: 13.0810
# Epoch 916/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 309.7947 - root_mean_squared_error: 17.6010 - mean_absolute_error: 13.0844
# Epoch 917/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 309.4894 - root_mean_squared_error: 17.5923 - mean_absolute_error: 13.0786
# Epoch 918/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 309.5898 - root_mean_squared_error: 17.5952 - mean_absolute_error: 13.0703
# Epoch 919/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 309.0729 - root_mean_squared_error: 17.5805 - mean_absolute_error: 13.0712
# Epoch 920/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 309.1008 - root_mean_squared_error: 17.5813 - mean_absolute_error: 13.0912
# Epoch 921/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 308.9112 - root_mean_squared_error: 17.5759 - mean_absolute_error: 13.0837
# Epoch 922/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 308.4132 - root_mean_squared_error: 17.5617 - mean_absolute_error: 13.0735
# Epoch 923/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 308.0119 - root_mean_squared_error: 17.5503 - mean_absolute_error: 13.0622
# Epoch 924/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 308.0025 - root_mean_squared_error: 17.5500 - mean_absolute_error: 13.0358
# Epoch 925/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 307.3765 - root_mean_squared_error: 17.5322 - mean_absolute_error: 13.0256
# Epoch 926/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 307.8361 - root_mean_squared_error: 17.5453 - mean_absolute_error: 13.0515
# Epoch 927/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 306.9406 - root_mean_squared_error: 17.5197 - mean_absolute_error: 13.0270
# Epoch 928/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 306.5228 - root_mean_squared_error: 17.5078 - mean_absolute_error: 12.9969
# Epoch 929/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 306.3825 - root_mean_squared_error: 17.5038 - mean_absolute_error: 12.9859
# Epoch 930/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 306.1687 - root_mean_squared_error: 17.4977 - mean_absolute_error: 12.9778
# Epoch 931/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 306.0832 - root_mean_squared_error: 17.4952 - mean_absolute_error: 12.9725
# Epoch 932/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 305.8269 - root_mean_squared_error: 17.4879 - mean_absolute_error: 12.9677
# Epoch 933/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 305.7110 - root_mean_squared_error: 17.4846 - mean_absolute_error: 12.9532
# Epoch 934/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 305.8703 - root_mean_squared_error: 17.4891 - mean_absolute_error: 12.9501
# Epoch 935/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 305.8109 - root_mean_squared_error: 17.4875 - mean_absolute_error: 12.9412
# Epoch 936/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 305.5564 - root_mean_squared_error: 17.4802 - mean_absolute_error: 12.9433
# Epoch 937/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 305.4852 - root_mean_squared_error: 17.4781 - mean_absolute_error: 12.9472
# Epoch 938/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 304.8286 - root_mean_squared_error: 17.4593 - mean_absolute_error: 12.9389
# Epoch 939/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 304.3316 - root_mean_squared_error: 17.4451 - mean_absolute_error: 12.9397
# Epoch 940/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 304.9828 - root_mean_squared_error: 17.4638 - mean_absolute_error: 12.9604
# Epoch 941/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 303.7603 - root_mean_squared_error: 17.4287 - mean_absolute_error: 12.9518
# Epoch 942/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 303.6158 - root_mean_squared_error: 17.4246 - mean_absolute_error: 12.9509
# Epoch 943/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 303.4267 - root_mean_squared_error: 17.4191 - mean_absolute_error: 12.9579
# Epoch 944/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 303.1570 - root_mean_squared_error: 17.4114 - mean_absolute_error: 12.9665
# Epoch 945/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 302.7949 - root_mean_squared_error: 17.4010 - mean_absolute_error: 12.9625
# Epoch 946/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 302.6263 - root_mean_squared_error: 17.3962 - mean_absolute_error: 12.9532
# Epoch 947/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 302.5034 - root_mean_squared_error: 17.3926 - mean_absolute_error: 12.9503
# Epoch 948/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 302.4090 - root_mean_squared_error: 17.3899 - mean_absolute_error: 12.9649
# Epoch 949/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 302.0972 - root_mean_squared_error: 17.3809 - mean_absolute_error: 12.9624
# Epoch 950/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 302.0754 - root_mean_squared_error: 17.3803 - mean_absolute_error: 12.9750
# Epoch 951/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 301.9016 - root_mean_squared_error: 17.3753 - mean_absolute_error: 12.9678
# Epoch 952/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 301.0838 - root_mean_squared_error: 17.3518 - mean_absolute_error: 12.9405
# Epoch 953/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 300.9367 - root_mean_squared_error: 17.3475 - mean_absolute_error: 12.9296
# Epoch 954/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 300.8673 - root_mean_squared_error: 17.3455 - mean_absolute_error: 12.9221
# Epoch 955/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 300.6119 - root_mean_squared_error: 17.3382 - mean_absolute_error: 12.9168
# Epoch 956/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 300.4063 - root_mean_squared_error: 17.3322 - mean_absolute_error: 12.9123
# Epoch 957/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 299.9666 - root_mean_squared_error: 17.3195 - mean_absolute_error: 12.9112
# Epoch 958/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 299.9546 - root_mean_squared_error: 17.3192 - mean_absolute_error: 12.9253
# Epoch 959/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 299.9257 - root_mean_squared_error: 17.3184 - mean_absolute_error: 12.9269
# Epoch 960/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 299.5572 - root_mean_squared_error: 17.3077 - mean_absolute_error: 12.9258
# Epoch 961/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 299.3992 - root_mean_squared_error: 17.3032 - mean_absolute_error: 12.9262
# Epoch 962/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 299.1430 - root_mean_squared_error: 17.2958 - mean_absolute_error: 12.9192
# Epoch 963/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 298.5556 - root_mean_squared_error: 17.2788 - mean_absolute_error: 12.9020
# Epoch 964/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 298.4303 - root_mean_squared_error: 17.2751 - mean_absolute_error: 12.8914
# Epoch 965/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 298.7503 - root_mean_squared_error: 17.2844 - mean_absolute_error: 12.8822
# Epoch 966/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 298.9552 - root_mean_squared_error: 17.2903 - mean_absolute_error: 12.8683
# Epoch 967/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 298.6829 - root_mean_squared_error: 17.2824 - mean_absolute_error: 12.8640
# Epoch 968/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 298.2184 - root_mean_squared_error: 17.2690 - mean_absolute_error: 12.8645
# Epoch 969/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 298.3447 - root_mean_squared_error: 17.2727 - mean_absolute_error: 12.8747
# Epoch 970/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 297.6390 - root_mean_squared_error: 17.2522 - mean_absolute_error: 12.8646
# Epoch 971/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 297.5060 - root_mean_squared_error: 17.2484 - mean_absolute_error: 12.8626
# Epoch 972/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 297.2444 - root_mean_squared_error: 17.2408 - mean_absolute_error: 12.8612
# Epoch 973/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 296.9949 - root_mean_squared_error: 17.2335 - mean_absolute_error: 12.8782
# Epoch 974/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 297.7964 - root_mean_squared_error: 17.2568 - mean_absolute_error: 12.9022
# Epoch 975/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 296.9822 - root_mean_squared_error: 17.2332 - mean_absolute_error: 12.8904
# Epoch 976/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 296.5784 - root_mean_squared_error: 17.2215 - mean_absolute_error: 12.8850
# Epoch 977/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 297.0631 - root_mean_squared_error: 17.2355 - mean_absolute_error: 12.8924
# Epoch 978/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 296.0745 - root_mean_squared_error: 17.2068 - mean_absolute_error: 12.8702
# Epoch 979/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 295.7140 - root_mean_squared_error: 17.1963 - mean_absolute_error: 12.8620
# Epoch 980/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 296.0428 - root_mean_squared_error: 17.2059 - mean_absolute_error: 12.8681
# Epoch 981/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 295.5624 - root_mean_squared_error: 17.1919 - mean_absolute_error: 12.8716
# Epoch 982/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 295.0956 - root_mean_squared_error: 17.1783 - mean_absolute_error: 12.8587
# Epoch 983/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.8913 - root_mean_squared_error: 17.1724 - mean_absolute_error: 12.8365
# Epoch 984/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.6154 - root_mean_squared_error: 17.1644 - mean_absolute_error: 12.8251
# Epoch 985/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.6412 - root_mean_squared_error: 17.1651 - mean_absolute_error: 12.8231
# Epoch 986/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.6138 - root_mean_squared_error: 17.1643 - mean_absolute_error: 12.8161
# Epoch 987/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.4581 - root_mean_squared_error: 17.1598 - mean_absolute_error: 12.8118
# Epoch 988/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.7119 - root_mean_squared_error: 17.1672 - mean_absolute_error: 12.8135
# Epoch 989/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.5066 - root_mean_squared_error: 17.1612 - mean_absolute_error: 12.7978
# Epoch 990/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.3592 - root_mean_squared_error: 17.1569 - mean_absolute_error: 12.7974
# Epoch 991/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 294.4799 - root_mean_squared_error: 17.1604 - mean_absolute_error: 12.7997
# Epoch 992/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 293.8972 - root_mean_squared_error: 17.1434 - mean_absolute_error: 12.7916
# Epoch 993/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 293.9620 - root_mean_squared_error: 17.1453 - mean_absolute_error: 12.7970
# Epoch 994/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 293.4545 - root_mean_squared_error: 17.1305 - mean_absolute_error: 12.7914
# Epoch 995/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 293.0884 - root_mean_squared_error: 17.1198 - mean_absolute_error: 12.7876
# Epoch 996/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 292.8737 - root_mean_squared_error: 17.1136 - mean_absolute_error: 12.7898
# Epoch 997/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 292.5905 - root_mean_squared_error: 17.1053 - mean_absolute_error: 12.8019
# Epoch 998/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 292.4097 - root_mean_squared_error: 17.1000 - mean_absolute_error: 12.8106
# Epoch 999/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 292.6438 - root_mean_squared_error: 17.1068 - mean_absolute_error: 12.8195
# Epoch 1000/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 292.1180 - root_mean_squared_error: 17.0915 - mean_absolute_error: 12.8170
# 2/2 [==============================] - 0s 2ms/step

# %%
show_result(y_test, predicted)

# %% [markdown]
# # Recurrent neural network

# %% [markdown]
# We discussed in the theory section that recurrent neural networks can be very good
# at modeling long-term relationships between points in a time-series. Let's set up an
# RNN.
#
# We'll use the same dataset as before – the univariate values of airline passengers. In
# this case, our network is going to need a sequence of points for each training sample.
# At each training step, the RNN is going to be trained on points (passengers) leading
# up to the next passenger number.
#
# Please note that we can use TensorFlow (or even statsmodels' lagmat()) utility
# functions for this purpose (and we will use them in Chapter 12, Case Studies), but in
# this instance, we'll write this quickly ourselves.
#
# We'll need to resample our passenger numbers thus:

# %%
from statsmodels.tsa.tsatools import lagmat
LOOKBACK = 4

dataset = pd.DataFrame(
    lagmat(passengers, maxlag=LOOKBACK+1)[LOOKBACK+1:, :]
).rename(columns={LOOKBACK: "passengers"})

display(passengers.head())
dataset.head()
# Out:
#             passengers  year  month
# date
# 1949-01-31       112.0     0      0
# 1949-02-28       118.0     0      1
# 1949-03-31       132.0     0      2
# 1949-04-30       129.0     0      3
# 1949-05-31       121.0     0      4
#        0    1    2      3  passengers    5      6    7    8      9   10   11  \
# 0  121.0  0.0  4.0  129.0         0.0  3.0  132.0  0.0  2.0  118.0  0.0  1.0
# 1  135.0  0.0  5.0  121.0         0.0  4.0  129.0  0.0  3.0  132.0  0.0  2.0
# 2  148.0  0.0  6.0  135.0         0.0  5.0  121.0  0.0  4.0  129.0  0.0  3.0
# 3  148.0  0.0  7.0  148.0         0.0  6.0  135.0  0.0  5.0  121.0  0.0  4.0
# 4  136.0  0.0  8.0  148.0         0.0  7.0  148.0  0.0  6.0  135.0  0.0  5.0
#
#       12   13   14
# 0  112.0  0.0  0.0
# 1  118.0  0.0  1.0
# 2  132.0  0.0  2.0
# 3  129.0  0.0  3.0
# 4  121.0  0.0  4.0

# %%
def wrap_data(df, lookback: int):
    """Wrap the data into a format that is compatible with the LSTM model."""
    dataset = []
    for index in range(lookback, len(df) + 1):
        features = {
            f"col_{i}": float(val)
            for i, val in enumerate(df.iloc[index - lookback : index].values)
        }
        row = pd.DataFrame.from_dict([features])
        row.index = [df.index[index - 1]]
        dataset.append(row)
    return pd.concat(dataset, axis=0)

# %% [markdown]
# This function does the job. It goes over all the points in the dataset and takes a
# sequence leading up to it. The number of points in the new sequence is defined by
# the parameter lookback.
#
# Let's put it to use:

# %%
passengers = get_passengers()

dataset = wrap_data(passengers, lookback=LOOKBACK)
dataset = dataset.join(passengers.shift(-1))
dataset.head()
# Out:
#             col_0  col_1  col_2  col_3  passengers
# 1949-04-30  112.0  118.0  132.0  129.0       121.0
# 1949-05-31  118.0  132.0  129.0  121.0       135.0
# 1949-06-30  132.0  129.0  121.0  135.0       148.0
# 1949-07-31  129.0  121.0  135.0  148.0       148.0
# 1949-08-31  121.0  135.0  148.0  148.0       136.0

# %% [markdown]
# We are using a lookback of 10. I've deliberately chosen a value that is not optimal.
# I'm leaving it as an exercise to the reader to choose one that's better and try it out.
#
# The last line in the code above joins the targets (lookahead 1) together with the
# sequences.
#
# We are ready to define our network, but let's get the imports out of the way:

# %%
import tensorflow.keras as keras
from tensorflow.keras.layers import Input, Bidirectional, LSTM, Dense
import tensorflow as tf

# %%
print(f"Model shape: {(len(passengers.columns)-1, 1)}")
# Out:
# Model shape: (0, 1)

# %%
def create_model(passengers):
    input_layer = Input(shape=(len(passengers.columns)-1, 1))
    recurrent = Bidirectional(LSTM(
        10,
        #dropout=0.1,
        #recurrent_dropout=0.1,
        activation="selu"
    ))(input_layer)
    output_layer = Dense(1)(recurrent)
    model = keras.models.Model(inputs=input_layer, outputs=output_layer)
    model.compile(
        loss="mse",
        optimizer=keras.optimizers.Adam(),
        metrics=[
            keras.metrics.RootMeanSquaredError(),
            keras.metrics.MeanAbsoluteError(),
        ],
    )
    return model

# %% [markdown]
# It's a bidirectional LSTM network. The result of the last layer is projected linearly as
# our output. I've set the activation function of the LSTM to tanh in case you want to
# run this on a GPU runtime, so it will benefit from NVIDIA's GPU-accelerated library
# cuDNN. We are extracting the same metrics as in the previous practice.
#
# A few more preliminaries that you should be familiar with from the previous section
# are as follows:

# %%
from sklearn.model_selection import train_test_split

callback = tf.keras.callbacks.EarlyStopping(monitor="loss", patience=10)
model = create_model(dataset)
X_train, X_test, y_train, y_test = train_test_split(
    dataset.drop(columns="passengers"), dataset["passengers"], shuffle=False
)

# %%
y_train
# Out:
# 1949-04-30    121.0
# 1949-05-31    135.0
# 1949-06-30    148.0
# 1949-07-31    148.0
# 1949-08-31    136.0
#               ...
# 1957-08-31    404.0
# 1957-09-30    347.0
# 1957-10-31    305.0
# 1957-11-30    336.0
# 1957-12-31    340.0
# Name: passengers, Length: 105, dtype: float64

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[callback])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 2s 3ms/step - loss: 55491.0938 - root_mean_squared_error: 235.5655 - mean_absolute_error: 217.4839
# Epoch 2/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 39082.9492 - root_mean_squared_error: 197.6941 - mean_absolute_error: 176.0365
# Epoch 3/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 9071.2461 - root_mean_squared_error: 95.2431 - mean_absolute_error: 84.7783
# Epoch 4/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 3247.0596 - root_mean_squared_error: 56.9830 - mean_absolute_error: 48.1994
# Epoch 5/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2201.1030 - root_mean_squared_error: 46.9159 - mean_absolute_error: 36.1750
# Epoch 6/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2643.0093 - root_mean_squared_error: 51.4102 - mean_absolute_error: 36.5052
# Epoch 7/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2685.6145 - root_mean_squared_error: 51.8229 - mean_absolute_error: 36.6560
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2484.3284 - root_mean_squared_error: 49.8430 - mean_absolute_error: 36.1329
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2367.7170 - root_mean_squared_error: 48.6592 - mean_absolute_error: 36.0124
# Epoch 10/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2242.4077 - root_mean_squared_error: 47.3541 - mean_absolute_error: 35.6454
# Epoch 11/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2179.3943 - root_mean_squared_error: 46.6840 - mean_absolute_error: 35.6557
# Epoch 12/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2159.5544 - root_mean_squared_error: 46.4710 - mean_absolute_error: 35.5594
# Epoch 13/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2089.2839 - root_mean_squared_error: 45.7087 - mean_absolute_error: 35.2269
# Epoch 14/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2002.2465 - root_mean_squared_error: 44.7465 - mean_absolute_error: 34.3499
# Epoch 15/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1829.3101 - root_mean_squared_error: 42.7704 - mean_absolute_error: 33.1501
# Epoch 16/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1893.9204 - root_mean_squared_error: 43.5192 - mean_absolute_error: 32.7794
# Epoch 17/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1898.1857 - root_mean_squared_error: 43.5682 - mean_absolute_error: 32.8650
# Epoch 18/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1692.9681 - root_mean_squared_error: 41.1457 - mean_absolute_error: 32.0570
# Epoch 19/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1773.3296 - root_mean_squared_error: 42.1109 - mean_absolute_error: 32.8181
# Epoch 20/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1698.2888 - root_mean_squared_error: 41.2103 - mean_absolute_error: 32.0453
# Epoch 21/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1656.0732 - root_mean_squared_error: 40.6949 - mean_absolute_error: 31.5995
# Epoch 22/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1655.6935 - root_mean_squared_error: 40.6902 - mean_absolute_error: 31.5551
# Epoch 23/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1649.0626 - root_mean_squared_error: 40.6087 - mean_absolute_error: 31.3824
# Epoch 24/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1621.0911 - root_mean_squared_error: 40.2628 - mean_absolute_error: 31.4006
# Epoch 25/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1651.7847 - root_mean_squared_error: 40.6422 - mean_absolute_error: 31.9402
# Epoch 26/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1559.1536 - root_mean_squared_error: 39.4861 - mean_absolute_error: 30.9470
# Epoch 27/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1549.9248 - root_mean_squared_error: 39.3691 - mean_absolute_error: 30.3769
# Epoch 28/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1589.8130 - root_mean_squared_error: 39.8725 - mean_absolute_error: 30.3346
# Epoch 29/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1640.6918 - root_mean_squared_error: 40.5055 - mean_absolute_error: 30.5773
# Epoch 30/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1557.3982 - root_mean_squared_error: 39.4639 - mean_absolute_error: 30.4396
# Epoch 31/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1579.7802 - root_mean_squared_error: 39.7464 - mean_absolute_error: 30.4365
# Epoch 32/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1556.0132 - root_mean_squared_error: 39.4463 - mean_absolute_error: 29.9958
# Epoch 33/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1562.7661 - root_mean_squared_error: 39.5318 - mean_absolute_error: 29.8992
# Epoch 34/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1490.9675 - root_mean_squared_error: 38.6130 - mean_absolute_error: 29.2215
# Epoch 35/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1513.3800 - root_mean_squared_error: 38.9022 - mean_absolute_error: 29.3153
# Epoch 36/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1477.5527 - root_mean_squared_error: 38.4389 - mean_absolute_error: 30.1006
# Epoch 37/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1399.1526 - root_mean_squared_error: 37.4052 - mean_absolute_error: 28.7651
# Epoch 38/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1436.6686 - root_mean_squared_error: 37.9034 - mean_absolute_error: 28.7462
# Epoch 39/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1541.3724 - root_mean_squared_error: 39.2603 - mean_absolute_error: 29.5947
# Epoch 40/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1451.2991 - root_mean_squared_error: 38.0959 - mean_absolute_error: 28.7480
# Epoch 41/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1417.8551 - root_mean_squared_error: 37.6544 - mean_absolute_error: 28.1987
# Epoch 42/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1352.3079 - root_mean_squared_error: 36.7737 - mean_absolute_error: 27.6321
# Epoch 43/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1409.8853 - root_mean_squared_error: 37.5484 - mean_absolute_error: 28.4040
# Epoch 44/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1369.6521 - root_mean_squared_error: 37.0088 - mean_absolute_error: 28.0549
# Epoch 45/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1498.0371 - root_mean_squared_error: 38.7045 - mean_absolute_error: 28.9352
# Epoch 46/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1474.1899 - root_mean_squared_error: 38.3952 - mean_absolute_error: 28.7493
# Epoch 47/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1331.0070 - root_mean_squared_error: 36.4830 - mean_absolute_error: 27.1858
# Epoch 48/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1310.9327 - root_mean_squared_error: 36.2068 - mean_absolute_error: 27.3528
# Epoch 49/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1330.1399 - root_mean_squared_error: 36.4711 - mean_absolute_error: 27.1189
# Epoch 50/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1301.6740 - root_mean_squared_error: 36.0787 - mean_absolute_error: 26.7449
# Epoch 51/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1385.3063 - root_mean_squared_error: 37.2197 - mean_absolute_error: 27.5055
# Epoch 52/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1355.8877 - root_mean_squared_error: 36.8224 - mean_absolute_error: 27.1381
# Epoch 53/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1306.8942 - root_mean_squared_error: 36.1510 - mean_absolute_error: 26.5385
# Epoch 54/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1392.2323 - root_mean_squared_error: 37.3126 - mean_absolute_error: 27.7875
# Epoch 55/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1275.7220 - root_mean_squared_error: 35.7173 - mean_absolute_error: 26.9510
# Epoch 56/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1256.7271 - root_mean_squared_error: 35.4503 - mean_absolute_error: 26.2231
# Epoch 57/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1284.4185 - root_mean_squared_error: 35.8388 - mean_absolute_error: 26.3127
# Epoch 58/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1241.4182 - root_mean_squared_error: 35.2338 - mean_absolute_error: 26.1180
# Epoch 59/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1269.4958 - root_mean_squared_error: 35.6300 - mean_absolute_error: 26.7315
# Epoch 60/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1148.4055 - root_mean_squared_error: 33.8881 - mean_absolute_error: 26.0814
# Epoch 61/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1282.0453 - root_mean_squared_error: 35.8057 - mean_absolute_error: 26.9591
# Epoch 62/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1181.1381 - root_mean_squared_error: 34.3677 - mean_absolute_error: 25.9404
# Epoch 63/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1047.3240 - root_mean_squared_error: 32.3624 - mean_absolute_error: 24.4815
# Epoch 64/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1048.6925 - root_mean_squared_error: 32.3835 - mean_absolute_error: 23.9293
# Epoch 65/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 960.9441 - root_mean_squared_error: 30.9991 - mean_absolute_error: 23.6990
# Epoch 66/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 942.8279 - root_mean_squared_error: 30.7055 - mean_absolute_error: 23.5788
# Epoch 67/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1036.5134 - root_mean_squared_error: 32.1949 - mean_absolute_error: 23.9121
# Epoch 68/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1073.7434 - root_mean_squared_error: 32.7680 - mean_absolute_error: 24.2715
# Epoch 69/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1159.3578 - root_mean_squared_error: 34.0493 - mean_absolute_error: 26.1991
# Epoch 70/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1226.9906 - root_mean_squared_error: 35.0284 - mean_absolute_error: 27.1635
# Epoch 71/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1035.4363 - root_mean_squared_error: 32.1782 - mean_absolute_error: 24.8669
# Epoch 72/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1268.7278 - root_mean_squared_error: 35.6192 - mean_absolute_error: 25.4046
# Epoch 73/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1283.5714 - root_mean_squared_error: 35.8270 - mean_absolute_error: 25.7119
# Epoch 74/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1427.4418 - root_mean_squared_error: 37.7815 - mean_absolute_error: 29.9933
# Epoch 75/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1085.9336 - root_mean_squared_error: 32.9535 - mean_absolute_error: 24.6184
# Epoch 76/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1274.3467 - root_mean_squared_error: 35.6980 - mean_absolute_error: 28.0872

# %%
predicted = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
show_result(y_test, predicted)

# %% [markdown]
# # Dilated causal convolutional neural network
#
# This example is based on Krist Papadopoulos's SeriesNet implementation of the paper "Conditional Time-Series Forecasting with Convolutional Neural Networks," by Anastasia Borovykh and others.
#
# We'll implement this model together and we'll apply it to two datasets to see how it does out of the box. I won't be going through tweaking the data and architecture in this example.
#
# First, the imports:

# %%
import numpy as np
import pandas as pd
from keras.layers import Conv1D, Input, Add, Activation, Dropout
from keras.models import Sequential, Model
from keras.layers import LeakyReLU, ELU
from keras import optimizers
import tensorflow as tf

# %% [markdown]
# What is perhaps surprising is how easy it is to do a causal convolution in TensorFlow. Conv1D comes with a parameter, padding, which can be specified as 'causal'. This simply pads the layer's input with zeros according to the causal nature, where output at time t only depends on the previous time steps, <t. Please refer to the discussion in the ConvNets section in this chapter.
#
# This means that we can predict the values of early time steps in the frame.
#
# The main idea of this network is a residual block with causal convolutions. This code segment constructs the corresponding network architecture:

# %%
def DC_CNN_Block(nb_filter, filter_length, dilation):
    """DC CNN block."""
    def f(input_):
        residual = input_
        layer_out = Conv1D(
            filters=nb_filter,
            kernel_size=filter_length,
            dilation_rate=dilation,
            activation="linear",
            padding="causal",
            use_bias=True,
        )(input_)
        layer_out = Activation("selu")(layer_out)
        skip_out = Conv1D(
            1, 1, activation="linear", use_bias=False
        )(layer_out)
        network_in = Conv1D(
            1, 1, activation="linear", use_bias=False
        )(layer_out)
        network_out = Add()([residual, network_in])
        return network_out, skip_out

    return f

# %% [markdown]
# I've simplified this a bit to make it easier to read.
# The network itself just stacks these layers as a SkipNet follows up with a
# convolution:

# %%
def DC_CNN_Model(length):
    """Model for DC CNN."""
    input = Input(shape=(length, 1))
    l1a, l1b = DC_CNN_Block(32, 2, 1)(input)
    l2a, l2b = DC_CNN_Block(32, 2, 2)(l1a)
    l3a, l3b = DC_CNN_Block(32, 2, 4)(l2a)
    l4a, l4b = DC_CNN_Block(32, 2, 8)(l3a)
    l5a, l5b = DC_CNN_Block(32, 2, 16)(l4a)
    l6a, l6b = DC_CNN_Block(32, 2, 32)(l5a)
    l6b = Dropout(0.1)(l6b)
    l7a, l7b = DC_CNN_Block(32, 2, 64)(l6a)
    l7b = Dropout(0.1)(l7b)
    l8 = Add()([l1b, l2b, l3b, l4b, l5b, l6b, l7b])
    l9 = Activation("relu")(l8)
    l21 = Conv1D(1, 1, activation="linear", use_bias=False)(l9)
    model = Model(inputs=input, outputs=l21)
    model.compile(
        loss="mae",
        optimizer=optimizers.Adam(),
        metrics=[
            keras.metrics.RootMeanSquaredError(),
            keras.metrics.MeanAbsoluteError(),
            keras.metrics.MeanSquaredError()
        ],
    )
    return model

# %% [markdown]
# This is for a univariate time-series. For a multivariate time-series, some changes are necessary, which we won't cover here.
#
# Let's forecast passenger numbers again. We'll load the DataFrame as in the previous practice sections:

# %%
passengers = get_passengers()

# %%
passengers.head()
# Out:
#             passengers
# date
# 1949-01-31       112.0
# 1949-02-28       118.0
# 1949-03-31       132.0
# 1949-04-30       129.0
# 1949-05-31       121.0

# %% [markdown]
# We'll split this again into test and training sets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    passengers.passengers[:-1],
    passengers.passengers.shift(-1)[:-1],  # trick to remove the last value (NaN)
    shuffle=False
)

# %% [markdown]
# We'll train the model with this function:

# %%
def fit_model(timeseries):
    """Fit the model."""
    length = len(timeseries) - 1
    model = DC_CNN_Model(length)
    model.summary()
    X = timeseries[:-1].reshape(1, length, 1)
    y = timeseries[1:].reshape(1, length, 1)
    model.fit(X, y, epochs=3000, callbacks=[callback])
    return model

# %% [markdown]
# This function will do the forecast for us:

# %%
def forecast(model, timeseries):
    """Forecast the next `horizon` steps."""
    length = len(timeseries) - 1
    pred_array = np.zeros(length).reshape(1, length, 1)
    X_test_initial = timeseries[1:].reshape(1, length, 1)
    pred_array[:, 0, :] = model.predict(X_test_initial)[:, -1:, :]
    for i in range(length - 1):
        pred_array[:, i + 1 :, :] = model.predict(
            np.append(X_test_initial[:, i + 1 :, :], pred_array[:, : i + 1, :]).reshape(
                1, length, 1
            )
        )[:, -1:, :]
    return pred_array.flatten()

# %% [markdown]
# The forecast is created by predicting the immediate next future value based on the
# previous predictions. The parameter horizon is the forecast horizon.
#
# We'll put this together as a single function for convenience:

# %%
def evaluate_timeseries(series):
    """Evaluate the model on the given timeseries."""
    model = fit_model(series)
    pred_array = forecast(model, series)
    return pred_array, model

# %% [markdown]
# Now we are ready for training. We'll run everything like this:

# %%
predictions, model = evaluate_timeseries(
    X_train.values.reshape(-1, 1),
)
# Out:
# Model: "model_18"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_34 (InputLayer)          [(None, 106, 1)]     0           []
#
#  conv1d_66 (Conv1D)             (None, 106, 32)      96          ['input_34[0][0]']
#
#  activation_24 (Activation)     (None, 106, 32)      0           ['conv1d_66[0][0]']
#
#  conv1d_68 (Conv1D)             (None, 106, 1)       32          ['activation_24[0][0]']
#
#  add_24 (Add)                   (None, 106, 1)       0           ['input_34[0][0]',
#                                                                   'conv1d_68[0][0]']
#
#  conv1d_69 (Conv1D)             (None, 106, 32)      96          ['add_24[0][0]']
#
#  activation_25 (Activation)     (None, 106, 32)      0           ['conv1d_69[0][0]']
#
#  conv1d_71 (Conv1D)             (None, 106, 1)       32          ['activation_25[0][0]']
#
#  add_25 (Add)                   (None, 106, 1)       0           ['add_24[0][0]',
#                                                                   'conv1d_71[0][0]']
#
#  conv1d_72 (Conv1D)             (None, 106, 32)      96          ['add_25[0][0]']
#
#  activation_26 (Activation)     (None, 106, 32)      0           ['conv1d_72[0][0]']
#
#  conv1d_74 (Conv1D)             (None, 106, 1)       32          ['activation_26[0][0]']
#
#  add_26 (Add)                   (None, 106, 1)       0           ['add_25[0][0]',
#                                                                   'conv1d_74[0][0]']
#
#  conv1d_75 (Conv1D)             (None, 106, 32)      96          ['add_26[0][0]']
#
#  activation_27 (Activation)     (None, 106, 32)      0           ['conv1d_75[0][0]']
#
#  conv1d_77 (Conv1D)             (None, 106, 1)       32          ['activation_27[0][0]']
#
#  add_27 (Add)                   (None, 106, 1)       0           ['add_26[0][0]',
#                                                                   'conv1d_77[0][0]']
#
#  conv1d_78 (Conv1D)             (None, 106, 32)      96          ['add_27[0][0]']
#
#  activation_28 (Activation)     (None, 106, 32)      0           ['conv1d_78[0][0]']
#
#  conv1d_80 (Conv1D)             (None, 106, 1)       32          ['activation_28[0][0]']
#
#  add_28 (Add)                   (None, 106, 1)       0           ['add_27[0][0]',
#                                                                   'conv1d_80[0][0]']
#
#  conv1d_81 (Conv1D)             (None, 106, 32)      96          ['add_28[0][0]']
#
#  activation_29 (Activation)     (None, 106, 32)      0           ['conv1d_81[0][0]']
#
#  conv1d_83 (Conv1D)             (None, 106, 1)       32          ['activation_29[0][0]']
#
#  add_29 (Add)                   (None, 106, 1)       0           ['add_28[0][0]',
#                                                                   'conv1d_83[0][0]']
#
#  conv1d_84 (Conv1D)             (None, 106, 32)      96          ['add_29[0][0]']
#
#  activation_30 (Activation)     (None, 106, 32)      0           ['conv1d_84[0][0]']
#
#  conv1d_82 (Conv1D)             (None, 106, 1)       32          ['activation_29[0][0]']
#
#  conv1d_85 (Conv1D)             (None, 106, 1)       32          ['activation_30[0][0]']
#
#  conv1d_67 (Conv1D)             (None, 106, 1)       32          ['activation_24[0][0]']
#
#  conv1d_70 (Conv1D)             (None, 106, 1)       32          ['activation_25[0][0]']
#
#  conv1d_73 (Conv1D)             (None, 106, 1)       32          ['activation_26[0][0]']
#
#  conv1d_76 (Conv1D)             (None, 106, 1)       32          ['activation_27[0][0]']
#
#  conv1d_79 (Conv1D)             (None, 106, 1)       32          ['activation_28[0][0]']
#
#  dropout_14 (Dropout)           (None, 106, 1)       0           ['conv1d_82[0][0]']
#
#  dropout_15 (Dropout)           (None, 106, 1)       0           ['conv1d_85[0][0]']
#
#  add_31 (Add)                   (None, 106, 1)       0           ['conv1d_67[0][0]',
#                                                                   'conv1d_70[0][0]',
#                                                                   'conv1d_73[0][0]',
#                                                                   'conv1d_76[0][0]',
#                                                                   'conv1d_79[0][0]',
#                                                                   'dropout_14[0][0]',
#                                                                   'dropout_15[0][0]']
#
#  activation_31 (Activation)     (None, 106, 1)       0           ['add_31[0][0]']
#
#  conv1d_87 (Conv1D)             (None, 106, 1)       1           ['activation_31[0][0]']
#
# ==================================================================================================
# Total params: 1,089
# Trainable params: 1,089
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/3000
# 1/1 [==============================] - 2s 2s/step - loss: 385.3963 - root_mean_squared_error: 407.6720 - mean_absolute_error: 385.3963 - mean_squared_error: 166196.4688
# Epoch 2/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 374.6077 - root_mean_squared_error: 396.2423 - mean_absolute_error: 374.6077 - mean_squared_error: 157007.9688
# Epoch 3/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 366.0541 - root_mean_squared_error: 387.8706 - mean_absolute_error: 366.0541 - mean_squared_error: 150443.6250
# Epoch 4/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 349.8557 - root_mean_squared_error: 370.1926 - mean_absolute_error: 349.8557 - mean_squared_error: 137042.5312
# Epoch 5/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 338.8906 - root_mean_squared_error: 359.2753 - mean_absolute_error: 338.8906 - mean_squared_error: 129078.7656
# Epoch 6/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 330.2214 - root_mean_squared_error: 351.5173 - mean_absolute_error: 330.2214 - mean_squared_error: 123564.4453
# Epoch 7/3000
# 1/1 [==============================] - 0s 15ms/step - loss: 313.0863 - root_mean_squared_error: 330.9133 - mean_absolute_error: 313.0863 - mean_squared_error: 109503.5859
# Epoch 8/3000
# 1/1 [==============================] - 0s 15ms/step - loss: 304.6973 - root_mean_squared_error: 323.0549 - mean_absolute_error: 304.6973 - mean_squared_error: 104364.4453
# Epoch 9/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 290.5971 - root_mean_squared_error: 306.9921 - mean_absolute_error: 290.5971 - mean_squared_error: 94244.1484
# Epoch 10/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 278.1340 - root_mean_squared_error: 294.0793 - mean_absolute_error: 278.1340 - mean_squared_error: 86482.6328
# Epoch 11/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 263.5002 - root_mean_squared_error: 277.7606 - mean_absolute_error: 263.5002 - mean_squared_error: 77150.9453
# Epoch 12/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 252.1041 - root_mean_squared_error: 266.9985 - mean_absolute_error: 252.1041 - mean_squared_error: 71288.1953
# Epoch 13/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 247.2857 - root_mean_squared_error: 262.4923 - mean_absolute_error: 247.2857 - mean_squared_error: 68902.2344
# Epoch 14/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 243.9958 - root_mean_squared_error: 258.0609 - mean_absolute_error: 243.9958 - mean_squared_error: 66595.3984
# Epoch 15/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 238.3906 - root_mean_squared_error: 251.7729 - mean_absolute_error: 238.3906 - mean_squared_error: 63389.5742
# Epoch 16/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 238.3433 - root_mean_squared_error: 253.4437 - mean_absolute_error: 238.3433 - mean_squared_error: 64233.7305
# Epoch 17/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 234.1464 - root_mean_squared_error: 249.5337 - mean_absolute_error: 234.1464 - mean_squared_error: 62267.0469
# Epoch 18/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 233.6767 - root_mean_squared_error: 248.3129 - mean_absolute_error: 233.6767 - mean_squared_error: 61659.3164
# Epoch 19/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 233.4220 - root_mean_squared_error: 248.3369 - mean_absolute_error: 233.4220 - mean_squared_error: 61671.1992
# Epoch 20/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 232.3003 - root_mean_squared_error: 247.1149 - mean_absolute_error: 232.3003 - mean_squared_error: 61065.7695
# Epoch 21/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 232.0890 - root_mean_squared_error: 246.8307 - mean_absolute_error: 232.0890 - mean_squared_error: 60925.3711
# Epoch 22/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 232.5878 - root_mean_squared_error: 247.2095 - mean_absolute_error: 232.5878 - mean_squared_error: 61112.5312
# Epoch 23/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 231.2820 - root_mean_squared_error: 246.1718 - mean_absolute_error: 231.2820 - mean_squared_error: 60600.5312
# Epoch 24/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.6083 - root_mean_squared_error: 246.3752 - mean_absolute_error: 231.6083 - mean_squared_error: 60700.7188
# Epoch 25/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.7717 - root_mean_squared_error: 246.4661 - mean_absolute_error: 231.7717 - mean_squared_error: 60745.5391
# Epoch 26/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.6487 - root_mean_squared_error: 246.4076 - mean_absolute_error: 231.6487 - mean_squared_error: 60716.7070
# Epoch 27/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.4128 - root_mean_squared_error: 246.2846 - mean_absolute_error: 231.4128 - mean_squared_error: 60656.1055
# Epoch 28/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.4164 - root_mean_squared_error: 246.2127 - mean_absolute_error: 231.4164 - mean_squared_error: 60620.6797
# Epoch 29/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.7965 - root_mean_squared_error: 246.5508 - mean_absolute_error: 231.7965 - mean_squared_error: 60787.2734
# Epoch 30/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.2123 - root_mean_squared_error: 246.1230 - mean_absolute_error: 231.2123 - mean_squared_error: 60576.5430
# Epoch 31/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.3627 - root_mean_squared_error: 246.2192 - mean_absolute_error: 231.3627 - mean_squared_error: 60623.9141
# Epoch 32/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.9167 - root_mean_squared_error: 246.5484 - mean_absolute_error: 231.9167 - mean_squared_error: 60786.1133
# Epoch 33/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 231.0359 - root_mean_squared_error: 246.0306 - mean_absolute_error: 231.0359 - mean_squared_error: 60531.0742
# Epoch 34/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.1576 - root_mean_squared_error: 246.0981 - mean_absolute_error: 231.1576 - mean_squared_error: 60564.2539
# Epoch 35/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.2372 - root_mean_squared_error: 246.1600 - mean_absolute_error: 231.2372 - mean_squared_error: 60594.7461
# Epoch 36/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.1500 - root_mean_squared_error: 246.0860 - mean_absolute_error: 231.1500 - mean_squared_error: 60558.3398
# Epoch 37/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.2687 - root_mean_squared_error: 246.1715 - mean_absolute_error: 231.2687 - mean_squared_error: 60600.3867
# Epoch 38/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.0989 - root_mean_squared_error: 246.0639 - mean_absolute_error: 231.0989 - mean_squared_error: 60547.4297
# Epoch 39/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.0501 - root_mean_squared_error: 246.0358 - mean_absolute_error: 231.0501 - mean_squared_error: 60533.6055
# Epoch 40/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 231.2021 - root_mean_squared_error: 246.1304 - mean_absolute_error: 231.2021 - mean_squared_error: 60580.1680
# Epoch 41/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.1841 - root_mean_squared_error: 246.1239 - mean_absolute_error: 231.1841 - mean_squared_error: 60576.9727
# Epoch 42/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.0738 - root_mean_squared_error: 246.0498 - mean_absolute_error: 231.0738 - mean_squared_error: 60540.5078
# Epoch 43/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 231.1496 - root_mean_squared_error: 246.0947 - mean_absolute_error: 231.1496 - mean_squared_error: 60562.5742
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
HORIZON = len(y_test)

show_result(y_test[:HORIZON], predictions[:HORIZON], "Passengers")
